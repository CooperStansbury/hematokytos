# %%
import pickle

# %%
def load_pickle_as_dict(filename):
    with open(filename, 'rb') as f:
        data = pickle.load(f)
    if isinstance(data, dict):
        return data
    else:
        raise ValueError("The pickle file does not contain a dictionary.")
        
fpath = "/scratch/indikar_root/indikar1/cstansbu/hematokytos/test/240920_geneformer_cellClassifier_hsc/hsc_eval_metrics_dict.pkl"
fpath = "/scratch/indikar_root/indikar1/cstansbu/hematokytos/test/240920_geneformer_cellClassifier_hsc/ksplit1/hsc_pred_dict.pkl"
d = load_pickle_as_dict(fpath)
d
# Out:
# {'pred_ids': [15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   7,
#   15,
#   15,
#   15,
#   15,
#   7,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   6,
#   15,
#   15,
#   6,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   6,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15,
#   15],
#  'label_ids': [15,
#   6,
#   4,
#   12,
#   9,
#   15,
#   1,
#   14,
#   6,
#   1,
#   6,
#   14,
#   6,
#   15,
#   15,
#   9,
#   6,
#   6,
#   15,
#   15,
#   14,
#   4,
#   7,
#   7,
#   7,
#   14,
#   14,
#   4,
#   17,
#   7,
#   3,
#   4,
#   15,
#   15,
#   14,
#   6,
#   4,
#   9,
#   15,
#   12,
#   8,
#   9,
#   15,
#   14,
#   7,
#   6,
#   14,
# ...
