# %%
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import h5py
import scipy.sparse as sp
import time

import anndata as an
import scanpy as sc

# %%
fpath = "/nfs/turbo/umms-indikar/shared/projects/HSC/data/datasets/gomes_2018/gomes.h5ad"
adata = sc.read_h5ad(fpath)
adata
# Out:
# /home/cstansbu/miniconda3/envs/scanpy/lib/python3.12/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# AnnData object with n_obs × n_vars = 286 × 56269
#     obs: 'cell_type', 'cell_num'
#     layers: 'raw_counts'

# %%
# %%time
outpath = "/nfs/turbo/umms-indikar/shared/projects/HSC/pipeline_outputs/integrated_anndata/capybara/gomes_ref.h5ad"

aggdata = sc.get.aggregate(
    adata,
    by='cell_type',
    func='sum',
)

aggdata.X = aggdata.layers['sum']
del aggdata.layers['sum']
print(f"{aggdata.shape=}")
aggdata.write(outpath)
aggdata.obs.head()
# Out:
# aggdata.shape=(5, 56269)
# CPU times: user 33.9 ms, sys: 11 ms, total: 44.9 ms
# Wall time: 71.8 ms
# /home/cstansbu/miniconda3/envs/scanpy/lib/python3.12/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
#       cell_type
# DAY2       DAY2
# DAY15     DAY15
# DAY25     DAY25
# HDF         HDF
# UCB         UCB

# %%
aggdata
# Out:
# AnnData object with n_obs × n_vars = 5 × 56269
#     obs: 'cell_type'
